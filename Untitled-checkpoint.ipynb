# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import numpy as np
ax = plt.gca()
r = Rectangle((0.1,0.1), 0.5, 0.5, fill=False, ec="r")
ax.add_patch(r)
xl,xu = 0.1, 0.6
yl,yu = 0.1, 0.6
plt.gcf().canvas.mpl_connect('button_press_event', click)

def click(event):

    x= event.xdata
    y= event.ydata
    #check if click is inside axes
    if event.inaxes:
        if (xl <=x <= xu and yl<=y <=yu):
            plt.text(x, y, 'o')
        else: 
            plt.text(x, y, 'x')
plt.draw()
plt.show()
plt.savefig("Prob 1Fig")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.linspace(-2*math.pi,2*math.pi,40)
y = np.linspace(-2.5,2.5,40)
plt11 = sin(x)
plt12 = 2*sin(x)
plt21 = cos(x)
plt22 = 2*cos(x)

#Plot 1
fig = plt.gcf()
dsize = fig.get_size_inches()
fig.set_size_inches(2*dsize[0],dsize[1])
#fig = plt.figure()
ax = plt.subplot(121)
ax.plot(x, plt11,'b',label='sin(x)')
ax.plot(x, plt12,'--r',label='2 sin(x)')
ax.legend()
ax.grid()
xcoords, ycoords = [0], [0]
ycoords = [0]
colors = ['black']
for xc, c in zip(xcoords,colors):
    plt.axvline(x=xc,label='line at x = {}'.format(xc), c=c)
    for yc, c in zip(ycoords,colors):
             plt.axhline(y=yc,label='line at y = {}'.format(yc), c=c)

#Plot 2
ay = plt.subplot(122)
ay.plot(x, plt21, 'b',label = 'cos(x)')
ay.plot(x, plt22, '--r',label = '2 cos(x)')
ay.legend()
ay.grid()
xcoords, ycoords = [0], [0]
colors = ['black']
for xc, c in zip(xcoords,colors):
    plt.axvline(x=xc,label='line at x = {}'.format(xc), c=c)
    for yc, c in zip(ycoords,colors):
             plt.axhline(y=yc,label='line at y = {}'.format(yc), c=c)
plt.show()

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

mean = 2
sd = 0.5
# Generate list of 1000 sample from normal distribution with mean=2 and sd=0.5
samples = np.random.normal(mean,sd,1000)

# Create a plot with bins=50 and histtype=step
plt.hist(samples, bins=50 ,histtype='step')
# Rotate X ticks with 45 degrees
plt.xticks(rotation= 45)
# Add y label
plt.ylabel("Frequency")
#Add plot title
plt.title('Lengths of Dogs in Greensboro in feet')
#Save the plot to a file called plot.png
plt.savefig('plot.png')
#Display the plot inline
plt.show()
